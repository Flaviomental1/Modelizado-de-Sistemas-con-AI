# %% [markdown]
# <a href="https://colab.research.google.com/github/Flaviomental1/Modelizado-de-Sistemas-con-AI/blob/main/Copia_de_Practica_Unidad_3_Preceptron_simple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Taller Práctico: Clasificación de Riesgo Crediticio con Perceptrón
# ## Contexto del Problema
# Una entidad financiera desea automatizar la aprobación de créditos pre-aprobados.
#
# Se cuenta con dos variables de entrada:
#
# * Puntaje Crediticio (Normalizado de 0 a 1).
#
# * Ratio de Ahorro (Dinero ahorrado vs ingresos anuales).
#
# El objetivo es entrenar un Perceptrón Simple en Keras para que aprenda la frontera de decisión que separa a los clientes de "Bajo Riesgo" (Clase 1) de los de "Alto Riesgo" (Clase 0).

# %% [markdown]
# ## Paso 1: Preparación del Entorno
# Cargamos las librerías necesarias y generamos un dataset sintético que represente este escenario.

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons, make_blobs

# Generamos datos: 300 clientes con 2 características
"""X, y = make_blobs(n_samples=300, centers=2, n_features=2, cluster_std=1.5, random_state=42)"""
x,y = make_moons(n_samples=300, noise=0.1, random_state=1)
X = np.array(x)
y = np.array(y)

# Visualización inicial
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='bwr', edgecolors='k')
plt.xlabel("Puntaje Crediticio")
plt.ylabel("Ratio de Ahorro")
plt.title("Distribución de Clientes")
plt.show()

# %% [markdown]
# ## Paso 2: Definición de la Arquitectura (Misión del Alumno)
# Debes definir un modelo secuencial que represente un Perceptrón Simple. Recuerda que para una clasificación binaria, la salida debe pasar por una función que comprima el valor entre 0 y 1.
#
# **Guía Técnica:**
#
# * Usa una capa Dense.
#
# * Como es un Perceptrón de una sola capa, units debe ser igual a 1.
#
# * El input_shape debe coincidir con la cantidad de variables de entrada (2).

# %%
from tensorflow.keras.layers import Input

# %%
# --- COMPLETA EL CÓDIGO AQUÍ ---
model = Sequential([
    Input(shape=(2,)),
    Dense(units=1, activation='sigmoid',kernel_regularizer='l2')
    # Define la capa Dense con 1 neurona y activación 'sigmoid'

])
# ------------------------------

# %% [markdown]
# ## Paso 3: Compilación del Sistema
# Para que el modelo aprenda, debemos definir el Optimizador (que gestiona la Tasa de Aprendizaje) y la Función de Pérdida (que mide el error).
#
# **Ayuda Sugerida:**
#
# * Para clasificación binaria, la pérdida estándar es binary_crossentropy.
#
# * Experimenta con diferentes valores en learning_rate (prueba con 0.01, 0.1 y 0.5).

# %%
# --- COMPLETA EL CÓDIGO AQUÍ ---
# Usa model.compile(...)
model.compile(# Define el optimizer usando tf.keras.optimizers.SGD y la loss adecuada.
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
    loss='binary_crossentropy',
metrics=['accuracy']
)


# ------------------------------

# %% [markdown]
# ## Paso 4: Entrenamiento y Regularización
# Es momento de ajustar los pesos. Vamos a entrenar el modelo, pero esta vez, presta atención a cómo el número de épocas afecta el resultado.
#
# **Instrucciones:**
#
# * Ejecuta el método .fit().
#
# * Prueba configurar el entrenamiento con 50 épocas.

# %%
# --- COMPLETA EL CÓDIGO AQUÍ ---
# history = model.fit(..., epochs=..., verbose=1)
history = model.fit(X, y, epochs=50, verbose=1)

# ------------------------------
# Out:
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1467 - loss: 2.5683
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4567 - loss: 1.5183
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5000 - loss: 0.9277
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5633 - loss: 0.5579
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8500 - loss: 0.3612
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9700 - loss: 0.2600
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9833 - loss: 0.2051
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9900 - loss: 0.1696
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.1461
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.1291
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.1164
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.1064
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0983
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0917
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0862
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0816
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0777
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0743
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0714
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0688
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0664
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0643
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0625
# Epoch 24/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0608
# Epoch 25/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0592
# Epoch 26/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0578
# Epoch 27/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0566
# Epoch 28/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0554
# Epoch 29/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0543
# Epoch 30/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0533
# Epoch 31/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0524
# Epoch 32/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0515
# Epoch 33/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0507
# Epoch 34/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0499
# Epoch 35/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0492
# Epoch 36/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0485
# Epoch 37/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0479
# Epoch 38/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0473
# Epoch 39/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0468
# Epoch 40/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0463
# Epoch 41/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0458
# Epoch 42/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0453
# Epoch 43/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0449
# Epoch 44/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0445
# Epoch 45/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0441
# Epoch 46/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0437
# Epoch 47/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0433
# Epoch 48/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0430
# Epoch 49/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0427
# Epoch 50/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0424

# %% [markdown]
# Mustra de los Pesos y Sego del entrenamiento.

# %%
pesos,sesgo = model.layers[0].get_weights()
print(f"Peso 1 : {pesos[0]} ,Peso 2 :{pesos[1]}, Sesgo :{sesgo}")
# Out:
# Peso 1 : [0.92749816] ,Peso 2 :[-0.32406768], Sesgo :[0.25331622]

# %% [markdown]
# ## Paso 5: Evaluación de Resultados
# Una vez entrenado, utilizaremos el siguiente bloque para visualizar la Frontera de Decisión que tu modelo ha construido.

# %%
def plot_frontier(X, y, model):
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1), np.arange(y_min, y_max, 0.1))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    plt.contourf(xx, yy, Z, alpha=0.4, cmap='bwr')
    plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', cmap='bwr')
    plt.show()

plot_frontier(X, y, model)
# Out:
# 1070/1070 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %% [markdown]
# ## Desafíos Extra
# **Impacto del Sesgo:** Si imprimes los pesos del modelo con model.get_weights(), ¿cuál es el valor del Bias?
#
# ¿Qué pasaría si fuera cero?
#
# **Regularización:** Regresa al Paso 2 e intenta agregar kernel_regularizer='l2' dentro de la capa Dense.
#
# ¿Notas algún cambio en la suavidad de la frontera o en el valor de los pesos?
#
# **No Linealidad:** Cambia el generador de datos por make_moons(n_samples=300, noise=0.1).
#
# ¿Es capaz el Perceptrón de una sola capa de separar estos datos? Justifica basándote en la teoría de Separabilidad Lineal.

# %% [markdown]
# RESPUESTA :

# %% [markdown]
# No. Solo puede separa datos que son lienealmente separables.
# Donde todos los puntos de una clase A generen un valor por arriba de un umbral y todos lo puntos de una clase B generen valor por abajo del mismo.
